# %% [markdown]
# #### Name :- Abhishek Ajay Avati
# #### Rollno:-33106
# #### Batch :-M-9
# #### ps       :- Regression technique

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sklearn
from sklearn import linear_model
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_scor

# %%
data=pd.read_csv("temperatures.csv")

# %%
# printing data
data
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
data.shape
# Out:
# (117, 18)

# %%
data.dtypes
# Out:
# YEAR         int64
# JAN        float64
# FEB        float64
# MAR        float64
# APR        float64
# MAY        float64
# JUN        float64
# JUL        float64
# AUG        float64
# SEP        float64
# OCT        float64
# NOV        float64
# DEC        float64
# ANNUAL     float64
# JAN-FEB    float64
# MAR-MAY    float64
# JUN-SEP    float64
# OCT-DEC    float64
# dtype: object

# %%
data.plot(x='YEAR', y='ANNUAL', style='o')
plt.title('YEAR vs ANNUAL')
plt.xlabel('YEAR')  
plt.ylabel('ANNUAL')  
plt.show()

# %%
months=data.columns[1:13]


print(months)
# Out:
# Index(['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
#        'NOV', 'DEC'],
#       dtype='object')

# %%
X=data[['YEAR']]
for i in range(12):
    regression=linear_model.LinearRegression()
    print("FOR MONTH "+(months[i]))
    y=data[months[i]]
    X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=69)
    m=regression.fit(X_train,Y_train)
    Y_pred=m.predict(X_test)
    #finding errors
    MAE1 = mean_absolute_error(Y_test,Y_pred)
    MSE1 = mean_squared_error(Y_test,Y_pred)
    RSE1 = r2_score(Y_test,Y_pred)
    plt.scatter(X_test,Y_test,color="red")
    plt.plot(X_test,regression.predict(X_test),color='black',linewidth=2.5)
    plt.title(" TEMPRATURE vs YEAR")
    plt.xlabel("YEAR")
    plt.ylabel((months[i])+" TEMPRATURE")
    plt.show()
    print('Mean Absolute Error = %.3f'%MAE1)
    print('Mean Squared Error = %.3f'%MSE1)
    print('RSE = %.3f\n'%RSE1)
# Out:
# FOR MONTH JAN
# Mean Absolute Error = 0.552
# Mean Squared Error = 0.547
# RSE = 0.354
#
# FOR MONTH FEB
# Mean Absolute Error = 0.790
# Mean Squared Error = 1.081
# RSE = 0.395
#
# FOR MONTH MAR
# Mean Absolute Error = 0.761
# Mean Squared Error = 0.884
# RSE = 0.327
#
# FOR MONTH APR
# Mean Absolute Error = 0.555
# Mean Squared Error = 0.539
# RSE = 0.315
#
# FOR MONTH MAY
# Mean Absolute Error = 0.447
# Mean Squared Error = 0.346
# RSE = 0.260
#
# FOR MONTH JUN
# Mean Absolute Error = 0.453
# Mean Squared Error = 0.294
# RSE = 0.146
#
# FOR MONTH JUL
# Mean Absolute Error = 0.316
# Mean Squared Error = 0.160
# RSE = 0.263
#
# FOR MONTH AUG
# Mean Absolute Error = 0.291
# Mean Squared Error = 0.136
# RSE = 0.499
#
# FOR MONTH SEP
# Mean Absolute Error = 0.305
# Mean Squared Error = 0.160
# RSE = 0.500
#
# FOR MONTH OCT
# Mean Absolute Error = 0.396
# Mean Squared Error = 0.283
# RSE = 0.461
#
# FOR MONTH NOV
# Mean Absolute Error = 0.369
# Mean Squared Error = 0.249
# RSE = 0.510
# ...
